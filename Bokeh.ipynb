# %%
# Out:
# Collecting bokeh
#   Downloading bokeh-3.6.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (1.3.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (2.1.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from bokeh) (6.4.1)
# Collecting xyzservices>=2021.09.1 (from bokeh)
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->bokeh) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Downloading bokeh-3.6.0-py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    --------------- ------------------------ 2.6/6.9 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 14.1 MB/s eta 0:00:00
# Downloading xyzservices-2024.9.0-py3-none-any.whl (85 kB)
# Installing collected packages: xyzservices, bokeh
# Successfully installed bokeh-3.6.0 xyzservices-2024.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import bokeh.io
import bokeh.plotting 
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f8153f12-8556-4109-8585-c84673c6e463">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers 
from bokeh.plotting import figure , output_file , show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')

p=figure(title ='test_flower')
p.xaxis.axis_label= "petal_length" 
p.yaxis.axis_label= "petal_width" 
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="fdb97374-f050-41f0-9851-ae984c5c3671" data-root-id="p1285" style="display: contents;"></div>

# %%
output_file('test.html')

p=figure(title ='test_flower')
p.xaxis.axis_label= "petal_length" 
p.yaxis.axis_label= "petal_width" 
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="e10da499-be61-45b3-be25-03c03439779f" data-root-id="p1237" style="display: contents;"></div>

# %%
x=[1, 2, 3, 4]
y=[3, 8, 4, 7]

output_file("line.html")
p= figure(title = "line chart")
p.line(x, y)
show(p)
# Out:
#   <div id="cc2def2a-816b-4e74-b361-7e45639f2b6a" data-root-id="p1467" style="display: contents;"></div>

# %%
x=[1, 2, 3, 4]
y=[3, 8, 4, 7]

output_file("line.html")
p= figure(title = "line chart")
p.scatter(x, y, size =20, fill_color ='red',legend_label ="this is my data")
show(p)
# Out:
#   <div id="e4d2d50b-9df2-4509-a79a-f20dd05f42a6" data-root-id="p1599" style="display: contents;"></div>
